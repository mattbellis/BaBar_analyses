# %%
# %load_ext autoreload
# %autoreload 2

import uproot
import awkward as ak

from hist import Hist

import matplotlib.pylab as plt
import numpy as np

import time

import os

import babar_analysis_tools as bat

import pandas as pd

# %%
infilename = '/home/bellis/babar_data_local/tiny_hydrogen/Data_Only_Run_1_UNBLINDED.parquet'

data = ak.from_parquet(infilename)

data

# %%
x = ak.flatten(data['nMass'])

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.hist(x, bins=100, range=(0.90,1.2));
plt.xlabel(r'$M_{pe^-}$ [GeV/c$^2$]', fontsize=18)

plt.subplot(1,2,2)
plt.hist(x, bins=100, range=(0.90,1.0));
plt.xlabel(r'$M_{pe^-}$ [GeV/c$^2$]', fontsize=18)

plt.tight_layout()
plt.savefig('mass_distribution_00.png')

# %%
#data['nd1Lund']
#data['nd2Lund']
x = data['nn']

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.hist(x, bins=10,range=(0.5,10.5))
plt.xlabel('# tiny H candidates', fontsize=18)

plt.subplot(1,2,2)
plt.hist(x, bins=10,range=(0.5,10.5))
plt.yscale('log')
plt.xlabel('# tiny H candidates', fontsize=18)

plt.tight_layout()
plt.savefig('number_of_candidates.png')

# %%
nn = data['nn']

mask_nn = (nn==1)

data_masked = data[mask_nn]

# %%
#p_selector = 'VeryLooseKMProtonSelection'
#e_selector = 'SuperLooseKMElectronMicroSelection'

p_selector = 'VeryTightKMProtonSelection'
e_selector = 'VeryTightKMElectronMicroSelection'

mask_pid_proton, mask_pid_electron = bat.PID_masks_tiny_hydrogen(data_masked,p_selector=p_selector,e_selector=e_selector)

#mask_pid_proton, mask_pid_electron = mask_pid

# %%
len(data_masked)

# %%
len(mask_pid_proton)

# %%
mask_pid = mask_pid_proton & mask_pid_electron 

mask_event_pid = ak.any(mask_pid, axis=-1)

# %%
data_masked_2 = data_masked[mask_event_pid]

# %%
x = ak.flatten(data_masked_2['nMass'])

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.hist(x, bins=100, range=(0.90,1.2));
plt.xlabel(r'$M_{pe^-}$ [GeV/c$^2$]', fontsize=18)

plt.subplot(1,2,2)
plt.hist(x, bins=100, range=(0.90,1.0));
plt.xlabel(r'$M_{pe^-}$ [GeV/c$^2$]', fontsize=18)

plt.tight_layout()
plt.savefig('mass_distribution_01.png')
#plt.savefig('mass_distribution_02.png')

# %%
x = ak.flatten(data_masked_2['nMass'])

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.hist(x, bins=100, range=(0.90,1.2));
plt.xlabel(r'$M_{pe^-}$ [GeV/c$^2$]', fontsize=18)

plt.subplot(1,2,2)
plt.hist(x, bins=60, range=(0.90,0.96));
plt.xlabel(r'$M_{pe^-}$ [GeV/c$^2$]', fontsize=18)

plt.tight_layout()
plt.savefig('mass_distribution_01.png')
#plt.savefig('mass_distribution_02.png')

# %%
x = ak.flatten(data_masked_2['nMass'])

plt.hist(x, bins=200, range=(0.95,1.2));
plt.yscale('log')

# %%
flsig = data_masked_2['npostFitFlightSignificance']
fl = data_masked_2['npostFitFlight']

xflsig = ak.flatten(flsig)
xfl = ak.flatten(fl)

plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
plt.hist(xflsig,bins=100, range=(0,100))
plt.xlabel('Flight length significance', fontsize=18)

plt.subplot(2,2,2)
plt.hist(xfl,bins=100, range=(0,100))
plt.xlabel('Flight length [cm]', fontsize=18)



plt.subplot(2,2,3)
plt.hist(xflsig,bins=100, range=(0,100))
plt.xlabel('Flight length significance', fontsize=18)
plt.yscale('log')

plt.subplot(2,2,4)
plt.hist(xfl,bins=100, range=(0,100))
plt.xlabel('Flight length [cm]', fontsize=18)
plt.yscale('log')


plt.tight_layout()
plt.savefig('flight_length.png')
;

# %%
flsig = data_masked_2['npostFitFlightSignificance']
fl = data_masked_2['npostFitFlight']

xflsig = ak.flatten(flsig)
xfl = ak.flatten(fl)


mask_fl = fl>1
#mask_fl = flsig>20


x = ak.flatten(data_masked_2['nMass'][mask_fl])
#x = ak.flatten(data_masked_2['nMass'])

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.hist(x, bins=100, range=(0.90,1.2));
plt.xlabel(r'$M_{pe^-}$ [GeV/c$^2$]', fontsize=18)

plt.subplot(1,2,2)
plt.hist(x, bins=100, range=(0.90,1.0));
plt.xlabel(r'$M_{pe^-}$ [GeV/c$^2$]', fontsize=18)

plt.tight_layout()
plt.savefig('mass_distribution_fl_cut.png')

# %%
len(data)
